# %%
import numpy as np
import pandas as pd
import mne

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
participants = pd.read_csv('../ds003498-download/participants.tsv', sep = '\t')
participants.index = np.arange(1, len(participants) + 1)
participants
participants.at[1,'epilepsy']
participants.shape
# Out:
#    participant_id   age  sex  hand epilepsy  ilae  nights outcome  \
# 1          sub-01   NaN  NaN   NaN      TLE     1       4       S
# 2          sub-02  33.0    M   NaN      TLE     1       2       S
# 3          sub-03  20.0    F   NaN      TLE     1       5       S
# 4          sub-04  20.0    F   NaN      TLE     1       6       S
# 5          sub-05  40.0    M   NaN      TLE     1       5       S
# 6          sub-06  48.0    M   NaN      TLE     1       5       S
# 7          sub-07  25.0    M   NaN      TLE     3       1       F
# 8          sub-08  21.0    F   NaN      TLE     3       2       F
# 9          sub-09  52.0    M   NaN      TLE     5       2       F
# 10         sub-10  37.0    M   NaN      ETE     1       1       S
# 11         sub-11  36.0    M   NaN      ETE     1       3       S
# 12         sub-12  49.0    M   NaN      ETE     1       4       S
# 13         sub-13  17.0    M   NaN      ETE     1       2       S
# ...

# %%
list_of_hfo_events = []
list_of_hfo_events1 = []
list_of_hfo_events_2 = []
Y_train = []


for i in range(1, 10):
    hfo = pd.read_csv(f'../ds003498-download/sub-0{i}/ses-interictalsleep/ieeg/sub-0{i}_ses-interictalsleep_run-01_events.tsv', sep = '\t')
    (x, y) = hfo.shape
    list_of_hfo_events1.append(hfo)
    for m in range (x):
          Y_train.append(participants.at[i, 'epilepsy'])

# %%
len(Y_train)
# Out:
# 31272

# %%
for i in range (11, 21):
    hfo = pd.read_csv(f'../ds003498-download/sub-{i}/ses-interictalsleep/ieeg/sub-{i}_ses-interictalsleep_run-01_events.tsv', sep = '\t')
    list_of_hfo_events_2.append(hfo)
    for m in range (x):
          Y_train.append(participants.at[i, 'epilepsy'])

# %%
list_of_hfo_events = list_of_hfo_events1 + list_of_hfo_events_2
hfo_events = pd.concat(list_of_hfo_events)
hfo_events
# Out:
#          onset  duration       trial_type  value  sample
# 0       0.0015    0.0160        fr_PHR1-2     21       3
# 1       0.0015    0.0515    ripple_AHR3-4     41       3
# 2       0.0525    0.0695     ripple_HL2-3     48     105
# 3       0.0530    0.0510     ripple_HL3-4     49     106
# 4       0.1795    0.0420    ripple_IAR1-2     50     359
# ...        ...       ...              ...    ...     ...
# 5748  299.7770    0.0450    ripple_OTL7-8     41  599554
# 5749  299.7820    0.0435    ripple_OTL6-7     40  599564
# 5750  299.8030    0.0800   ripple_OTL9-10     42  599606
# 5751  299.8295    0.0755  ripple_OTL13-14     33  599659
# 5752  299.8330    0.1155    ripple_OTL3-4     37  599666
#
# [195175 rows x 5 columns]

# %%
len(Y_train)
Y_train
# Out:
# 75882
# ['TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
#  'TLE',
# ...
